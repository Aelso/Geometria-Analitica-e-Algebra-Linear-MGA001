# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Geometria Analítica e Álgebra Linear** 🐇
# ###**Link**: https://ava.univesp.br/ultra/courses/_5942_1/cl/outline 🍺
# ##**Prof.Dr. Welington da Silva Cordeiro** 🤠
# ##**Aluno: Aelso Rocha Brito** 🐸
# ##**notebook**ComAnotaçõesDasVideoaulas 📖
# ## **Semestre:** 01.2022 ⚾
# ---

# %% [markdown]
# **PERGUNTA 1** 🕷
#
# Escolha a opção que apresenta em notação matricial o sistema:
#
# $\begin{cases}
# x+2y=2\\
# 2x-y=-1\\
# x+z=1
# \end{cases}$

# %% [markdown]
# a. $\begin{bmatrix} 1& 2& 0 \\ 2 &-1 & 0 \\ 1& 0& 1\end{bmatrix}
# \begin{bmatrix}x \\ y \\ z\end{bmatrix}=
# \begin{bmatrix}2\\-1\\ 1\end{bmatrix}$
# ## 🐫

# %% [markdown]
# b.$\begin{bmatrix}1& 2\\ 2&-1\\1& 1\end{bmatrix} \begin{bmatrix}x \\ y \\ z\end{bmatrix}=\begin{bmatrix}2\\-1\\ 1\end{bmatrix}$

# %% [markdown]
# c. $\begin{bmatrix}1& 2& 2\\ 2&-1 &-1\\1& 1& 1\end{bmatrix} \begin{bmatrix}x \\ y \\ z\end{bmatrix}=\begin{bmatrix}2 \\-1\\ 1\end{bmatrix}$

# %% [markdown]
# d.$\begin{bmatrix}1& 2& 0\\ 2&-1& 0\\1& 0& 1\end{bmatrix} \begin{bmatrix}2 \\-1 & \\ 1\end{bmatrix}=\begin{bmatrix}x \\y \\ z\end{bmatrix}$

# %% [markdown]
# e.$\begin{bmatrix}1&2& 1\\ 2&-1& 1\\1& 1& 1\end{bmatrix} \begin{bmatrix}x\\y\\ z\end{bmatrix}=\begin{bmatrix}2\\-1\\ 1\end{bmatrix}$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Note que $\begin{bmatrix} 1& 2& 0 \\ 2 &-1 & 0 \\ 1& 0& 1\end{bmatrix}$ é a matriz dos coeficientes, $\begin{bmatrix}x \\ y \\ z\end{bmatrix}$é a matriz das incógnitas e $\begin{bmatrix}2\\-1\\ 1\end{bmatrix}$ independentes. Portanto,$\begin{bmatrix} 1& 2& 0 \\ 2 &-1 & 0 \\ 1& 0& 1\end{bmatrix}
# \begin{bmatrix}x \\ y \\ z\end{bmatrix}=\begin{bmatrix}2\\-1\\ 1\end{bmatrix}$ é a resposta correta.

# %% [markdown]
# **PERGUNTA 2** 🐪
#
# Considere o seguinte sistema de equações lineares:
#
# $\begin{cases} 2x-y=3\\ x+4 w=- 2 \\x-y=7\\-z+3 w=8 \end{cases}$
#
# Selecione a opção que apresenta a classificação do sistema linear acima

# %% [markdown]
# a. É um sistema de 2 equações e 4 incógnitas.

# %% [markdown]
# b. É um sistema de 4 equações e 2 incógnitas

# %% [markdown]
# c. É um sistema de 4 equações e 3 incógnitas.

# %% [markdown]
# d. **É um sistema de 4 equações e 4 incógnitas.** 🐉

# %% [markdown]
# e. Este não é um sistema de equações lineares.

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Veja que cada linha desse sistema é uma equação. Portanto, temos 4 equações no total. As incógnitas do sistema são x, y, z e w , portanto o sistema tem 4 incógnitas.

# %% [markdown]
# **PERGUNTA 3** 👌
#
# Escolha a opção que mostra um sistema de equações lineares com 3 equações e 3 incógnitas.

# %% [markdown]
# a.$\begin{cases}2 x+y-z=5\\ x-2 y+3 z=- 1\\ 3 x-y+m=1 \end{cases}$

# %% [markdown]
# b.$\begin{cases}2 m+t=5\\ t-3 s=- 1\\-m+s=0 \end{cases}$
# ## 🦢

# %% [markdown]
# c.$\begin{cases} 2x+y-z=5\\ x^2-y+3z=- 1\\ 3 x-y+z=1 \end{cases}$

# %% [markdown]
# d. $\begin{bmatrix} 1& 2& 1 \\ 0& 1& 4 \\ 0& 1& 1 \end{bmatrix}$

# %% [markdown]
# e.$\begin{cases}2x+y-z=5 \\x-2 y+3 z=- 1 \end{cases}$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# A segunda equação do sistema $\begin{cases} 2x+y-z=5\\ x^2-y+3z=- 1\\ 3 x-y+z=1 \end{cases}$ não é uma equação linear, pois possui um termo quadrático $(x^2)$.
#
# A alternativa $\begin{bmatrix} 1& 2& 1 \\ 0& 1& 4 \\ 0& 1& 1 \end{bmatrix}$ é uma matriz, e não um sistema de equações lineares.
#
# O sistema $\begin{cases}2x+y-z=5 \\x-2 y+3 z=- 1 \end{cases}$ tem apenas 2 equações.
#
# O sistema $\begin{cases}2 x+y-z=5\\ x-2 y+3 z=- 1\\ 3 x-y+m=1 \end{cases}$ possui 4 incógnitas: x,y, z e m.
#
# A resposta correta é o sistema: $\begin{cases}2 m+t=5\\ t-3 s=- 1\\-m+s=0 \end{cases}$ que apresenta 3 equações e 3 incógnitas: m,t e s.

# %% [markdown]
# **PERGUNTA 4** 🌕
#
# Escolha a opção que apresenta a sequência de operações elementares que leva
#
# $\begin{bmatrix}1& 1& 2 \\ 1 &-2& -3 \\ 1&-1& 1\end{bmatrix}\begin{bmatrix}7 \\-7 \\0\end{bmatrix}$
# espaço até
# $\begin{bmatrix}1& 1& 2 \\ 0&-3& -5 \\0& 0& 1\end{bmatrix} \begin{bmatrix}7 \\-14\\ 1\end{bmatrix}$

# %% [markdown]
# a. $L3-L1,L2-L1,L3-(\frac{2}{3})L2,(\frac{3}{7})L3$
# ## ⛄

# %% [markdown]
# b. $L3-L1,L2-(2) L1,L3-(3) L2,(7) L3$

# %% [markdown]
# c. $L3-L1,L2-L1,L3-(\frac{2}{3})L2,\frac{5}L3$

# %% [markdown]
# d.$L3-(2) L1,L2-L1,L3-(2) L2,(3) L3$

# %% [markdown]
# e.$L3-L1,(5) L2-L1,L3-\frac{2}{3}L2,\frac{3}{7}L3$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Observe que os valores abaixo da diagonal principal da segunda matriz do enunciado são iguais a zero. Logo, precisamos utilizar o processo de escalonamento de matrizes.
#
# Para decidir a sequência de operações, basta olhar para os valores de cada linha e subtrair aquela que permite zerar, sucessivamente, os valores abaixo da diagonal principal.
#
# A letra “L” significa “linha” e o seu respectivo número acompanhado dessa letra indica o número da linha no sistema de equações apresentado.
#
# Portanto, L3 – L1 significa subtrair os valores da linha 3 com os valores da linha 1. Sabendo disso, basta fazer o cálculo diretamente para chegar no resultado:

# %% [markdown]
#  $\begin{bmatrix}1& 1& 2& 7 \\ 1 &-2& -3& -7\\ 1&-1& 1& 0\end{bmatrix}$ $\overrightarrow{L3-L1}$
#  $\begin{bmatrix}1& 1& 2& 7 \\ 1 &-2& -3& -7\\ 0&-2& -1& -7\end{bmatrix}$ $\overrightarrow{L2-L1}$
#  $\begin{bmatrix}1& 1& 2& 7 \\ 0 &-3& -5& -14\\ 0&-2& -1& -7\end{bmatrix}$ $\overrightarrow{L3-(\frac{2}{3})L2}$
#  $\begin{bmatrix}1& 1& 2& 7 \\ 0 &-3& -5& -14\\ 0& 0& \frac{7}{3}& \frac{7}{3}\end{bmatrix}$ $\overrightarrow{(\frac{3}{7})L3}$
#  $\begin{bmatrix}1& 1& 2& 7 \\ 0 &-3& -5& -14\\ 0& 0& 1& 1\end{bmatrix}$

# %% [markdown]
# **PERGUNTA 5** 🚂
#
# Assinale a alternativa que apresenta um sistema de equações lineares equivalente ao sistema:
# $\begin{cases}3 x+y=1\\ x-y=-9\end{cases}$

# %% [markdown]
# a.$\begin{cases}x+2y=12\\ 2x+2y=10 \end{cases}$
# ##🐎

# %% [markdown]
# b.$\begin{cases}3x+y=2\\ x-y=-9 \end{cases}$

# %% [markdown]
# c.$\begin{cases}3x+y=-9\\ x-y=1 \end{cases}$

# %% [markdown]
# d.$\begin{cases}x+2y=4 \\ x-y=-9\end{cases}$

# %% [markdown]
# e.$\begin{cases}3x+y=1\\ 2x+2 y=-9 \end{cases}$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Para que um sistema de equações lineares seja equivalente, eles precisam apresentar o mesmo conjunto solução. Sendo assim, basta notar que $x=-2$ e $y=7$ é solução do sistema do enunciado e da alternativa correta.

# %% [markdown]
# **PERGUNTA 6** 🐈
#
# Escolha a opção que apresenta um sistema linear impossível.

# %% [markdown]
# a.$\begin{cases}2x-y=0\\-3x+2y=0 \end{cases}$

# %% [markdown]
# b.	$\begin{cases}2 x-y=3 \\x+2 y=4 \end{cases}$

# %% [markdown]
# c.$\begin{cases}2x-y=0\\ x+2y=5\end{cases}$

# %% [markdown]
# d.$\begin{cases}2x-y=3\\-4x+2y=2 \end{cases}$
# ## 👽

# %% [markdown]
# e.$\begin{cases}2x-y=3\\ x+2y=4\\ 2x+4y=8 \end{cases}$

# %% [markdown]
# Comentário da resposta:**JUSTIFICATIVA**
#
# O sistema linear $\begin{cases}2x-y=3\\-4x+2y=2 \end{cases}$ possui equações incompatíveis. Para notar isso, basta multiplicar a primeira equação por 2, e subtrair o resultado pela segunda equação, assim teremos $0=8$.
