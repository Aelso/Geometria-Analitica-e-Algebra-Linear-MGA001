# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Geometria Analítica e Álgebra Linear** 🐇
# ###**Link**: https://ava.univesp.br/ultra/courses/_5942_1/cl/outline 🍺
# ##**Prof.Dr. Welington da Silva Cordeiro** 🤠
# ##**Aluno: Aelso Rocha Brito** 🐸
# ##**notebook**ComAnotaçõesDasVideoaulas 📖
# ## **Semestre:** 01.2022 ⚾
# ---

# %% [markdown]
# #**2|Sistemas Lineares** 🛸

# %% [markdown]
# Olá, estudantes! 💀
#
# Nesta semana, tematizaremos uma das principais aplicações da teoria de matrizes, que é a solução de Sistemas Lineares.
#
# Primeiramente, vamos apresentar a definição e as classificações dos sistemas lineares e discutiremos algumas formas de solução diretas destes sistemas. Depois, mostraremos como transformar um sistema linear em um problema envolvendo matrizes.
#
# Por fim, discutiremos o método do escalonamento, que é o método usado pela maioria dos softwares para solução de sistemas lineares. 🧨

# %% [markdown]
# **Objetivos de aprendizagem** 💎
#
# Ao final desta semana você deverá ser capaz de:
#
# 🐅 Entender o conceito de inversa de matrizes;
#
# 🐅Compreender os fundamentos de Sistemas Lineares;.
#
# 🐅Entender o algoritmo de escalonamento.

# %% [markdown]
# ##**Videoaula 4 - Sistemas lineares** 🍎
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-8307500_1;
#
# ####🎬Videoaula No YT:https://youtu.be/0kquQZdajk8;
# ---

# %% [markdown]
# **SISTEMA DE EQUAÇÕES LINEARES**

# %% [markdown]
# $\begin{cases}
# a_{11}x_{1}&a_{12}x_{2}&...&a_{1n}x_{n}=b_1\\
# a_{21}x_{2}&a_{22}x_{3}&...&a_{2n}x_{n}=b_2\\
# ...   &..... &...&......\\
# a_{m1}x_{1}&a_{m2}x_{2}&...&a_{mn}x_{n}=b_n
# \end{cases}$

# %% [markdown]
# **3 EQUAÇÕES E 3 INCÓGNITAS**

# %% [markdown]
# $\begin{cases}x+2y-z=1\\ 3x+y+z=0\\ 2x+3y+2z=2 \end{cases}$

# %% [markdown]
# $\begin{cases}m+2t-s=1\\ 3m+t+s=0\\ 2m+3t+2s=2 \end{cases}$

# %% [markdown]
# **4 EQUAÇÕES E 4 INCÓGNITAS**

# %% [markdown]
# $\begin{cases}x-y=1\\ y+z=2\\ z+2t=0\\ x-2z=7 \end{cases}$

# %% [markdown]
# **3 EQUAÇÕES E 2 INCÓGNITAS**

# %% [markdown]
# $\begin{cases}x-y=1\\ y+z=2\\ z+2t=0\\ x-2z=7 \end{cases}$

# %% [markdown]
# **SOLUÇÕES DE SISTEMAS DE EQUAÇÕES LINEARES**

# %% [markdown]
# $\begin{cases}x-y=1\\ x+2y=4\end{cases}$

# %% [markdown]
# $\begin{cases}x-y=1\\ x+2y=4\end{cases}$

# %% [markdown]
# $x=2$
#
# $y=1$

# %% [markdown]
# $\begin{cases}(x-x)+(2y-(-y))=(4-1)\\ 3y=3\end{cases}$

# %% [markdown]
# $\begin{cases}2x-y=-1\\ -2x+y=1\end{cases}$

# %% [markdown]
# $\begin{cases}(2x-2x)+(-y+y)=(-1+1)\\ 0=0\end{cases}$

# %% [markdown]
# $\begin{cases}2x-y=-1\\ -2x+y=1\end{cases}$

# %% [markdown]
# $\begin{cases}2x-y=-1\\ -2x+y=2\end{cases}$

# %% [markdown]
# $\begin{cases}(2x-2x)+(-y+y)=(-1+2)\\ 0=1\end{cases}$

# %% [markdown]
# $\begin{cases}2x-y=-1\\ -2x+y=2\end{cases}$

# %% [markdown]
# $\begin{cases}2x-y=-1\\ -2x+y=1\end{cases}$
#
# $\begin{cases}x-y=1\\ x+2y=4\end{cases}$
#
# $\begin{cases}2x-y=-1\\ -2x+y=2\end{cases}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.geogebra.org/graphing/yr7rjtnc

# %% [markdown]
# $\begin{cases}x-y=1\\ x+2y=4\end{cases}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.geogebra.org/graphing/xemb2hkj

# %% [markdown]
# $\begin{cases}2x-y=-1\\ -2x+y=2\end{cases}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.geogebra.org/graphing/g3uqehyu

# %% [markdown]
# **SOLUÇÕES DE SISTEMAS DE EQUAÇÕES LINEARES**
#
# 🐸 O sistema tem uma única solução
#
# 🐸 O sistema tem infinitas soluções
#
# 🐸 O sistema não tem solução

# %% [markdown]
# ##**Videoaula 5 - O problema A𝒙=b** 🥭
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-8307701_1;
#
# ####🎬Videoaula No YT:https://youtu.be/qDX-eT5ZpgU;
# ---

# %% [markdown]
# **FORMA MATRICIAL DE UM SISTEMA DE EQUAÇÕES LINEARES**

# %% [markdown]
# $\begin{cases}2x+y=2\\ y+z=1\\ x-z=3 \end{cases}$

# %% [markdown]
# $Ax=b$

# %% [markdown]
# $\begin{bmatrix}2& 1& 0\\ 0& 1& 1\\ 1& 0& -1\end{bmatrix}\begin{bmatrix}x \\y \\z\end{bmatrix}=\begin{bmatrix}2 \\1 \\3\end{bmatrix}$

# %% [markdown]
# $\begin{bmatrix}2& 1& 0& |& 2\\ 0& 1& 1& |& 1\\ 1& 0& -1& |&2\end{bmatrix}$

# %% [markdown]
# 🟡 O sistema tem uma única solução
#
# 🟡 O sistema tem infinitas soluções
#
# 🟡 O sistema não tem solução

# %% [markdown]
# **OPERAÇÕES ELEMENTARES**

# %% [markdown]
# $L_i ↔ L_j$
#
# $kL_i → L_i$
#
# $L_i + kL_j → L_i$

# %% [markdown]
# $\begin{bmatrix}2& 1& 2 \\ 1& 7& 1\\ 3& -3& -1\\2& 0& 1\end{bmatrix} l_2 ⇔  L_3\begin{bmatrix}2& 1& 2 \\ 3& -3& -1\\1& 7& 1\\2& 0& 1\end{bmatrix}$

# %% [markdown]
# $\begin{bmatrix}2& 1& 2 \\ 1& 7& 1\\ 3& -3& -1\\2& 0& 1\end{bmatrix} 4l_4 ⇔  L_4\begin{bmatrix}2& 1& 2 \\ 1& 7& 1\\ 3& -3& -1\\4& 0& 2\end{bmatrix}$

# %% [markdown]
# $\begin{bmatrix}2& 1& 2 \\ 1& 7& 1\\ 3& -3& -1\\2& 0& 1\end{bmatrix} l_2+2L_1 ⇒  L_2
# \begin{bmatrix}2& 1& 2 \\ 1+2(2)& 7+2(1)& 1+2(2)\\ 3& -3& -1\\4& 0& 2\end{bmatrix}=
# \begin{bmatrix}2& 1& 2 \\ 5& 9& 5\\ 3& -3& -1\\2& 0& 1\end{bmatrix}
# $

# %% [markdown]
# **ELIMINAÇÃO DE GAUSS**

# %% [markdown]
# $\begin{cases}x-y=1\\ x+2y=4\end{cases}$

# %% [markdown]
# $\begin{bmatrix}1& -1& |& 1\\ 1& 2& |& 4\end{bmatrix}$

# %% [markdown]
# $\begin{bmatrix}1& -1& |& 1\\ 1& 2& |& 4\end{bmatrix}
# L_2-L_1 ⇒ L_2
# \begin{bmatrix}1& -1& |& 1\\ 1-1& 2-(-1)& |& 4-1\end{bmatrix} =
# \begin{bmatrix}1& -1& |& 1\\ 0& 3& |& 3\end{bmatrix}$

# %% [markdown]
# $\begin{cases}x-y=1\\ 3y=3\end{cases}$

# %% [markdown]
# $x=2$
#
# $y=1$

# %% [markdown]
# $\begin{cases}x+2y-t=-1\\ -x-3y+z+2t=3\\x-y+4z+t=1\\ 2x-3y+7z+3t=4 \end{cases}$

# %% [markdown]
# $\begin{bmatrix}
# 1&  2&  0& -1&|&-1\\
# -1&-3&  1& 2& |& 3\\
# 1& -1&  4& 1& |& 1\\
# 2& -3&  7& 3& |& 4
# \end{bmatrix}$

# %% [markdown]
# $\begin{bmatrix}
# 1&  2&  0& -1&|&-1\\
# 0& -1&  1& 1& |& 2\\
# 0&  0&  1&-1& |&-4\\
# 0&  0&  0& -2&|&-8
# \end{bmatrix}
# \begin{bmatrix}
# 1&  2&  0& -1&|&-1\\
# -1&-3&  1& 2& |& 3\\
# 1& -1&  4& 1& |& 1\\
# 2& -3&  7& 3& |& 4
# \end{bmatrix}$

# %% [markdown]
# Matriz reduzida à forma escada

# %% [markdown]
# $\begin{bmatrix}
# 1&  2&  0& -1&|&-1\\
# -1&-3&  1& 2& |& 3\\
# 1& -1&  4& 1& |& 1\\
# 2& -3&  7& 3& |& 4
# \end{bmatrix}
# \begin{matrix}L_2+L_1 ⇒ L_2\\L_3-L_1⇒ L3\\L_4-2L_1⇒L_4\end{matrix}
# \begin{bmatrix}
# 1&  2&  0& -1&|&-1\\
# 0& -1&  1& 1& |& 2\\
# 0& -3&  4& 2& |& 2\\
# 0& -7&  7& 5& |& 6
# \end{bmatrix}$

# %% [markdown]
# $\begin{matrix}L_3-3L_2⇒ L_3\\L_4-7L_2⇒ L_4\end{matrix}
# \begin{bmatrix}
# 1&  2&  0& -1&|&-1\\
# 0& -1&  1& 1& |& 2\\
# 0&  0&  1& -1&|&-4\\
# 0& 0&   0& -2&|&-8
# \end{bmatrix}$

# %% [markdown]
# $\begin{cases}x+2y-t=-1\\ -y+z+t=2\\z-t=-4\\-2t=-8 \end{cases}$

# %% [markdown]
# $\begin{cases}x+2y-t=-1\\ -x-3y+z+2t=3\\x-y+4z+t=1\\ 2x-3y+7z+3t=4 \end{cases}$

# %% [markdown]
# $t=4$
#
# $z=0$
#
# $y=2$
#
# $x=-1$

# %% [markdown]
# $\begin{cases}x-y=1\\ x+2y=4\\-2x+2y=2\end{cases}$

# %% [markdown]
# $\begin{bmatrix}
# 1&  -1& |& 1\\
# 1&   2& |& 4\\
# -2&  2& |& -2
# \end{bmatrix}
# \begin{matrix}L_2-L_1⇒ L_2\\L_3+2L_1⇒ L_3\end{matrix}
# \begin{bmatrix}
# 1&  -1& |& 1\\
# 0&   3& |& 3\\
# 0&   0& |& 0
# \end{bmatrix}$

# %% [markdown]
# $\begin{cases}x-y=1\\ x+2y=4\\-2x+2y=2\end{cases}$

# %% [markdown]
# $\begin{cases}x-y=1\\ 3y=3\end{cases}$

# %% [markdown]
# $x=2$
#
# $y=1$

# %% [markdown]
# **O que vem por aí...** 🚂

# %% [markdown]
# 🌈 Determinantes de Matrizes quadradas
#
# 🌈  Inversa de Matrizes

# %% [markdown]
# [Texto base: Geometria Analítica I (Leia as páginas 27-50) | Doherty Andrade e Jorge Ferreira de Lacerda](https://ava.univesp.br/bbcswebdav/xid-8238238_1) 🟩

# %% [markdown]
# **Semana 2 - Aprofundando o tema** 🎺
#
# [Material de apoio: Equação linear | Portal da Matemática OBMEP](https://youtu.be/2yAIFFNZ91s)🎦
#
# [Material de apoio: Sistema linear | Portal da Matemática OBMEP](https://youtu.be/LbXVpm67kQk)🎦
#
# [Material de apoio: Métodos de solução de um sistema linear | Portal da Matemática OBMEP](https://youtu.be/v_503AxWUf0)🎦
#
# [Material de apoio: Escalonamento | Portal da Matemática OBMEP ](https://youtu.be/QmmYqR-7zm4)🎦
#
# [Material de apoio: Classificação de sistemas lineares | Portal da Matemática OBMEP](https://youtu.be/94kPf7TM0V0)🎦

# %% [markdown]
# [Semana 2 - Atividade Avaliativa](https://ava.univesp.br/webapps/blackboard/content/launchLink.jsp?course_id=_5942_1&content_id=_799202_1&mode=view) 🦅

# %% [markdown]
# **Em síntese - Semana 2** 🍃
#
# Nesta semana, você conheceu mais um dos temas centrais do curso: os sistemas lineares.
#
# Você está preparado para avançar? Faça uma auto-avaliação: você adquiriu todas as competências e habilidades esperadas? Marque os itens que acredita ter alcançado. Se faltar algum, revise o conteúdo da semana.
#
# Nesta semana, eu:
#
# 🎃 Identifiquei um sistema linear e sua classificação;
#
# 🎃 Compreendi a passagem de um sistema linear para forma matricial;
#
# 🎃 Compreendi os métodos de solução do sistema matricial.
