# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Geometria Analítica e Álgebra Linear** 🐇
# ###**Link**: https://ava.univesp.br/ultra/courses/_5942_1/cl/outline 🍺
# ##**Prof.Dr. Welington da Silva Cordeiro** 🤠
# ##**Aluno: Aelso Rocha Brito** 🐸
# ##**notebook**ComAnotaçõesDasVideoaulas 📖
# ## **Semestre:** 01.2022 ⚾
# ---

# %% [markdown]
# **PERGUNTA 1** 🦅
#
# Escolha a opção que tem o determinante da matriz A=$\begin{bmatrix}0&1& 0\\1& 1& 2\\1& 0& 1\end{bmatrix}$

# %% [markdown]
# a. $det(A) = π $

# %% [markdown]
# b. $det(A) = 1$ 🔥

# %% [markdown]
# c. $det(A) = 2$

# %% [markdown]
# d. $det(A) = -1$

# %% [markdown]
# e. $det(A) = 0$

# %% [markdown]
# Comentário da resposta:	 **JUSTIFICATIVA**
#
# Fazendo o cálculo do determinante, temos:
#
# ${det}\begin{bmatrix}0&1& 0\\1& 1& 2\\1& 0& 1\end{bmatrix} = (0)(1)(1)+(1)(2)(1)+(0)(1)(0)-(0)(1)(1)-(0)(2)(1)-(1)(1)(1)=1$

# %% [markdown]
# **PERGUNTA 2** 🪐
#
# Assinale a alternativa que apresenta o determinante da matriz A=$\begin{bmatrix}2& 1\\1& 1\end{bmatrix}$

# %% [markdown]
# a. $det(A) = 2$

# %% [markdown]
# b. $det(A) = -1$

# %% [markdown]
# c. $det(A) = π$

# %% [markdown]
# d. $det(A) = 0$

# %% [markdown]
# e. $det(A) = 1$ 🍎

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Fazendo o cálculo do determinante, temos:
#
# ${det(A)}={det}\begin{bmatrix}2& 1\\1& 1\end{bmatrix}=2(1)-1(1)=1$

# %% [markdown]
# **PERGUNTA 3** 👈
#
# Escolha a opção que possui o determinante da matriz
# A=
# $\begin{bmatrix}
# 0& 1& 2& 0& 1\\
# 0& 0& 0& 0& 0\\
# 1& 2& 5& 7& 1\\
# 1& 1& 0& 2& 1\\
# 1& 0& 1& 1& 1
# \end{bmatrix}$

# %% [markdown]
# a. $det(A) = -1$

# %% [markdown]
# b. $det(A) = 0$ 🏂

# %% [markdown]
# c. $det(A) = π$

# %% [markdown]
# d. $det(A) = 1$

# %% [markdown]
# e. $det(A) = 2$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Basta notar que a matriz A possui todos os elementos da segunda linha nulos, portanto, pelas propriedades dos determinantes, $det(A) = 0$

# %% [markdown]
# **PERGUNTA 4** 🦖
#
# Considere A=$\begin{bmatrix}2& 1\\1& 1\end{bmatrix}$  espaço e espaço B=$\begin{bmatrix}3& 2\\1& 5\end{bmatrix}$.
#
# Assinale a opção correta.

# %% [markdown]
# a. $det(AB) = 15$

# %% [markdown]
# b. $det(AB) = 13$ 🐇

# %% [markdown]
# c. $det(AB) = 17$

# %% [markdown]
# d. $det(AB) = 26$

# %% [markdown]
# e. $det(AB) = 1$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Usando as propriedades do determinante, temos:
#
# ${det}(A B)=({det}(A))({det}(B))=(1)(13)=13$

# %% [markdown]
# **PERGUNTA 5** 🧩
#
# Assinale a opção que possui a inversa da matriz A=$\begin{bmatrix}3& 2\\1& 1\end{bmatrix}$

# %% [markdown]
# a. $A^{-1}=\begin{bmatrix}1&-2\\-1&-3\end{bmatrix}$

# %% [markdown]
# b. $A^{-1}=\begin{bmatrix}\frac{1}{3}&\frac{1}{2}\\1& 1\end{bmatrix}$

# %% [markdown]
# c. $A^{-1}=\begin{bmatrix}1&-2\\-1& 3\end{bmatrix}$ 🐸

# %% [markdown]
# d. $A^{-1}=\begin{bmatrix}-3&-2\\-1&-1\end{bmatrix}$

# %% [markdown]
# e. $A^{-1}=\begin{bmatrix}1&-3\\-1& 2\end{bmatrix}$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# A multiplicação de uma matriz pela sua inversa deve resultar na matriz identidade. Calculando, temos:
#
# $\begin{bmatrix}3& 2\\1& 1\end{bmatrix} \begin{bmatrix} 1&-2\\ -1& 3\end{bmatrix}= \begin{bmatrix} (3)(1)&+&(2)(-1)& (3)(-2)&+&(2)(3)\\(1)(1)&+&(1)(-1)& (1)(-2)&+&(1)(3) \end{bmatrix} =\begin{bmatrix} 1&0\\0&1 \end{bmatrix}$

# %% [markdown]
# **PERGUNTA 6** 🖖
#
# Escolha a opção que possui o determinante da matriz
# A=$\begin{bmatrix}
# 1& 1& 2& 122\\
# 0& 1& 62& 4\\
# 0& 0& 5& 7\\
# 0& 0& 0& 1
# \end{bmatrix}$

# %% [markdown]
# a. $det(A) = -1$

# %% [markdown]
# b. $det(A) = 2$

# %% [markdown]
# c. $det(A) = 0$

# %% [markdown]
# d. $det(A) = 1$

# %% [markdown]
# e. $det(A) = 5$ 🚋

# %% [markdown]
# Comentário da resposta:	 **JUSTIFICATIVA**
#
# Note que A é uma matriz triangular, portanto, pelo teorema 3.3 do texto-base: Geometria Analítica I, o determinante de A é = ao produto dos elementos de sua diagonal principal.
#
# Calculando, ${det}(A)=(1)(1)(5)(1)=5$.

# %% [markdown]
# **PERGUNTA 7**
#
# Assinale a opção que possui a inversa da matriz A=$\begin{bmatrix}
# 2& 1& 3\\
# 1& 1& 3\\
# 3& 3& 9
# \end{bmatrix}$

# %% [markdown]
# a. **A matriz A não tem inversa.** 🦖

# %% [markdown]
# b. $A^{-1}=\begin{bmatrix}
# 1& 1& \frac{3}{2}\\
# 1&  1& \frac{3}{2}\\
# \frac{3}{2}& \frac{3}{2}& \frac{9}{2}
# \end{bmatrix}$

# %% [markdown]
# c. $A^{-1}=\begin{bmatrix}
# 3& 3& 9\\
# 1& 1& 3\\
# 2& 1& 3
# \end{bmatrix}$

# %% [markdown]
# d. $A^{-1}=\begin{bmatrix}
# \frac{1}{2}& 1&\frac{1}{3}\\
# 1& 1&\frac{1}{3}\\
# \frac{1}{3}&\frac{1}{3}& \frac{1}{9}
# \end{bmatrix}$

# %% [markdown]
# e. $A^{-1}=\begin{bmatrix}
# 9& 3& 3\\
# 3& 1& 1\\
# 3& 1& 2
# \end{bmatrix}$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# A terceira linha da matriz A é igual a 3 vezes a segunda linha da matriz 2, portanto o determinante de A é igual a zero, e por isso não tem inversa.

# %% [markdown]
# **PERGUNTA 8** 🍯
#
# Assinale a alternativa que apresenta uma matriz que possui inversa.

# %% [markdown]
# a. $A=\begin{bmatrix}
# 1& 2& 0\\
# 2&-1& 0\\
# 1& 3& 0
# \end{bmatrix}$

# %% [markdown]
# b. $A=\begin{bmatrix}
# 2& 1\\
# 4& 2
# \end{bmatrix}$

# %% [markdown]
# c. $A=\begin{bmatrix}
# 1& 2& 3\\
# 2& 4& 6\\
# 1& 3& 0
# \end{bmatrix}$

# %% [markdown]
# d. $ A=\begin{bmatrix}
# 2& 1\\
# 1& 1
# \end{bmatrix}$ 👹

# %% [markdown]
# e. $A=\begin{bmatrix}
# 1& 2& 1\\
# 0& 0& 0\\
# 1& 1& 4
# \end{bmatrix}$

# %% [markdown]
# Comentário da resposta:	**JUSTIFICATIVA**
#
# Pelo teorema 3.2 do texto-base: Geometria Analítica I, toda matriz que tem determinante diferente de zero possui inversa.
#
# Calculando, $A =\begin{bmatrix} 2& 1\\1& 1 \end{bmatrix} =(2)(1)-(1)(1)=1$
#
# Logo, $A =\begin{bmatrix} 2& 1\\1& 1 \end{bmatrix}$ tem inversa.
#
# $A =\begin{bmatrix} 1& 2& 1\\0& 0& 0\\1& 1& 4 \end{bmatrix}$ tem uma linha com todos os elementos nulos, logo, seu determinante é zero.
#
# Portanto, não tem inversa.
#
# $A =\begin{bmatrix} 1& 2& 0\\2&-1& 0\\1& 3& 0 \end{bmatrix}$ tem uma coluna com todos os elementos nulos, logo, seu determinante é zero.
#
# Portanto, não tem inversa.
#
# $A =\begin{bmatrix} 2& 1\\4& 2 \end{bmatrix}$ tem determinante igual a zero.
#
# Portanto, não tem inversa.
#
# $A =\begin{bmatrix} 1& 2& 3\\2& 4& 6\\1& 3& 0 \end{bmatrix}$ tem a linha 2 igual a duas vezes a linha 1, portanto, seu determinante é igual a zero.
#
# Portanto, não tem inversa.
